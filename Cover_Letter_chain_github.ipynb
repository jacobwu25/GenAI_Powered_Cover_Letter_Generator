# %%
#pip install langchain openai python-docx beautifulsoup4 requests gradio langchain-community tiktoken fake-useragent
# Out:
# Requirement already satisfied: langchain in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (0.2.7)
# Requirement already satisfied: openai in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (1.35.13)
# Requirement already satisfied: python-docx in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (1.1.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (4.12.3)
# Requirement already satisfied: requests in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (2.32.3)
# Requirement already satisfied: gradio in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (4.38.1)
# Requirement already satisfied: langchain-community in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (0.2.7)
# Requirement already satisfied: tiktoken in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (0.8.0)
# Requirement already satisfied: fake-useragent in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (1.5.1)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from langchain) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from langchain) (3.9.5)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.12 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from langchain) (0.2.18)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from langchain) (0.2.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from langchain) (0.1.85)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from langchain) (2.8.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from langchain) (8.5.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from openai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from openai) (0.27.0)
# Requirement already satisfied: sniffio in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from openai) (4.12.2)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from python-docx) (5.2.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from requests) (2024.7.4)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from gradio) (23.2.1)
# Requirement already satisfied: altair<6.0,>=5.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from gradio) (5.3.0)
# Requirement already satisfied: fastapi in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from gradio) (0.111.1)
# Requirement already satisfied: ffmpy in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from gradio) (0.3.2)
# Requirement already satisfied: gradio-client==1.1.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from gradio) (1.1.0)
# Requirement already satisfied: huggingface-hub>=0.19.3 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from gradio) (0.23.4)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from gradio) (6.4.0)
# Requirement already satisfied: jinja2<4.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from gradio) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from gradio) (3.9.1)
# Requirement already satisfied: orjson~=3.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from gradio) (3.10.6)
# Requirement already satisfied: packaging in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from gradio) (24.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<11.0,>=8.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from gradio) (10.4.0)
# Requirement already satisfied: pydub in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from gradio) (0.0.9)
# Requirement already satisfied: ruff>=0.2.2 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from gradio) (0.5.2)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from gradio) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from gradio) (0.12.3)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from gradio) (0.30.1)
# Requirement already satisfied: fsspec in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from gradio-client==1.1.0->gradio) (2024.6.1)
# Requirement already satisfied: websockets<12.0,>=10.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from gradio-client==1.1.0->gradio) (11.0.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from tiktoken) (2024.9.11)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from altair<6.0,>=5.0->gradio) (4.23.0)
# Requirement already satisfied: toolz in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from altair<6.0,>=5.0->gradio) (0.12.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: filelock in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (3.15.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.12->langchain) (1.33)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from matplotlib~=3.0->gradio) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from matplotlib~=3.0->gradio) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from matplotlib~=3.0->gradio) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from matplotlib~=3.0->gradio) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from matplotlib~=3.0->gradio) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from matplotlib~=3.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from pydantic<3,>=1->langchain) (2.20.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: colorama in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.7.1)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from fastapi->gradio) (0.37.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from fastapi->gradio) (0.0.4)
# Requirement already satisfied: email_validator>=2.0.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from fastapi->gradio) (2.2.0)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from email_validator>=2.0.0->fastapi->gradio) (2.6.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.12->langchain) (3.0.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=5.0->gradio) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=5.0->gradio) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=5.0->gradio) (0.19.0)
# Requirement already satisfied: six>=1.5 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.18.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from uvicorn[standard]>=0.12.0->fastapi->gradio) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from uvicorn[standard]>=0.12.0->fastapi->gradio) (1.0.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from uvicorn[standard]>=0.12.0->fastapi->gradio) (0.22.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hcwu2\onedrive\documents\visual_studio_project\cover_letter\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import os
import requests

#Ensure you already set up openai_api_key as an environment parameter before use the model
openai_api_key = os.getenv("openai_api_key")
os.environ["openai_api_key"] = openai_api_key
os.environ["OPENAI_MODEL_NAME"]="gpt-4o"
# Check if the API key was retrieved successfully
if openai_api_key is None:
    raise ValueError("OpenAI API key not found in environment variables.")

# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.chains import LLMChain
from langchain.chains import SequentialChain
from langchain.document_loaders import PyPDFLoader
import docx
from bs4 import BeautifulSoup

import tiktoken
from openai import OpenAIError  # Make sure you handle exceptions from OpenAI
import openai
from fake_useragent import UserAgent
import random
import time

# %%
llm_model = "gpt-4o"
llm = ChatOpenAI(temperature=0.0, model=llm_model)

# Token counting function with a check for non-string inputs
def count_tokens(text, model=llm_model):
    if not isinstance(text, str):
        return 0  # Return 0 tokens for non-string inputs
    encoding = tiktoken.encoding_for_model(model)
    return len(encoding.encode(text))

# %%
#Define prompt template
prompt_job_description = ChatPromptTemplate.from_template(
    "Your role is a tech job researcher. Your goal is to make sure to do amazing analysis on "
    "{job_description} to help job applicants."
    "As a Job Researcher, your prowess in "
        "navigating and extracting critical "
        "information from job postings is unmatched."
        "Your skills help pinpoint the necessary "
        "qualifications and skills sought "
        "by employers, forming the foundation for "
        "effective application tailoring."
)

# %%
prompt_profiler = ChatPromptTemplate.from_template(
    "Your role is a Personal Profiler for Job Candidate. Your goal is to do incredible research on job candidates"
    "to help them stand out in the job market"
    "Equipped with analytical prowess, you dissect "
    "and synthesize information "
    "from diverse sources to craft comprehensive "
    "personal and professional profiles, laying the "
    "groundwork for personalized cover letter enhancements. "
    "The sources of the information you are gonna use " 
    "are candidate's resume  and Linkedin profile. \n\n"
    "Resume: {resume} "
    "Linkedin profile: {linkedin} "
    "If Linkedin is missing, use ONLY resume to craft the profile. "
)

# %%
prompt_cover_letter_composer = ChatPromptTemplate.from_template(
    "Your role is a Cover Letter Writer for Job Candidates. "
    "Your goal is to compose a cover letter that is factually correct for the job application. "
    "With a strategic mind and an eye for detail, you "
    "excel at composing cover letters for applicants to tech companies. "
    "You understand what is important to recruiters "
    "in the tech space. "
    "You know how to highlight relevant skills and experiences, ensuring they "
    "resonate perfectly with the job's requirements. "
    "You are gonna use candidate's Personal Profile and the Job Description to craft an exceptional cover letter by using the Cover Letter Template provided below. \n\n"
    "Personal Profile: {personal_profile} \n "
    "Job Description: {job_summary} \n "
    "Cover Letter Template: {cover_letter_format} \n "
    "If Linkedin is missing, use ONLY resume to craft the profile. If Cover Letter Template is missing, you decide an appropriate format to use. "
)

# %%
prompt_proof_reader = ChatPromptTemplate.from_template(
    "Your role is to proofread cover letters. "
    "Your goal is to ensure there are no grammatical errors "
    "and that the meaning of the cover letter is concise. "
    "With an eye for detail, you are the final gatekeeper " 
    "to ensure a high-quality cover letter is generated for job applications. "
    "You will use the Cover Letter Draft from previous work to complete your work. "
    "You will also ensure that the final cover letter follows the Cover Letter Template as closely as possibl. \n\n"
    "Cover Letter Draft: {cover_letter_draft} \n "
    "Cover Letter Template: {cover_letter_format} "
    "If Cover Letter Template is missing, you decide an appropriate format to use. "
)

# %%
#Define individual chain and chain of thoughts
chain_one = LLMChain(llm=llm, prompt=prompt_job_description, output_key="job_summary")
chain_two = LLMChain(llm=llm, prompt=prompt_profiler, output_key="personal_profile")
chain_three = LLMChain(llm=llm, prompt=prompt_cover_letter_composer, output_key="cover_letter_draft")
chain_four = LLMChain(llm=llm, prompt= prompt_proof_reader, output_key="cover_letter_final")
#result = chain.run(input)
sequential_chain = SequentialChain(
    chains=[chain_one, chain_two, chain_three, chain_four],
    input_variables=["resume", "linkedin", "job_description", "cover_letter_format"],
    output_variables=["job_summary", "personal_profile", "cover_letter_draft", "cover_letter_final"],
    verbose=True
)

# %%
# Function to extract text from PDF
def extract_text_from_pdf(file):
    try:
        # Assuming 'file' is a file-like object
        file_path = file.name
        loader = PyPDFLoader(file_path)
        text = loader.load()
        return text
    except Exception as e:
        logging.error("Error extracting text from PDF", exc_info=True)
        return str(e)

# Function to extract text from DOCX
def extract_text_from_docx(file):
    doc = docx.Document(file)
    text = ""
    for paragraph in doc.paragraphs:
        text += paragraph.text + "\n"
    return text

# Rate limiter to slow down requests
def rate_limiter(min_wait=2, max_wait=5):
    delay = random.uniform(min_wait, max_wait)  # Random delay between requests
    time.sleep(delay)
    print(f"Rate limiter: Delaying for {delay:.2f} seconds.")

# Function to fetch job description from URL
def fetch_job_description(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
        job_description = soup.get_text(strip=True)
        # Check if the fetched content is too short to be meaningful
        if len(job_description) < 100:
            raise ValueError("Fetched job description content is too short.")
        return job_description
    except (requests.exceptions.RequestException, ValueError) as e:
        print(f"Error fetching job description: {e}")
        return None

# Function to fetch LinkedIn profile from URL
def fetch_linkedin_profile(url):
    ua = UserAgent()  # Create a UserAgent object
    headers = {
        'User-Agent': ua.random  # Randomly select a User-Agent for each request
    }
    try:
        # Apply rate limiter before making the request
        rate_limiter()  # Add a delay before each request
        
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Will raise an HTTPError for bad responses
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Extract LinkedIn profile text - adjust based on the structure of the LinkedIn profile page
        linkedin_profile = soup.get_text()
        return linkedin_profile
    except requests.exceptions.RequestException as e:
        print(f"Error fetching LinkedIn profile: {e}")
        return None

# %%
def cover_letter_gen(resume_file, linkedin_url, job_description_url, manual_job_description, cover_letter_file):
    # Extract text from the uploaded resume PDF
    resume_content = extract_text_from_pdf(resume_file)

    # Fetch job description from URL
    job_description = fetch_job_description(job_description_url)
    if not job_description:  # Check if job description is empty or too short
        job_description = manual_job_description.strip()
        if not job_description:
            return None, "Error: Job description could not be fetched and manual input is empty. Please provide a valid job description.", "", ""
        
    # Fetch LinkedIn profile from URL
    linkedin_profile = fetch_linkedin_profile(linkedin_url)
    if linkedin_profile is None or not linkedin_profile.strip():
        linkedin_profile = "LinkedIn profile could not be fetched."
        message = "Warning: LinkedIn profile could not be fetched. Continuing without LinkedIn profile data."
    else:
        message = "LinkedIn profile fetched successfully."
    
   
    # Check if cover letter file is provided
    if cover_letter_file is not None:
        # Determine the file type and extract text accordingly
        cover_letter_format = ""
        cover_letter_file_path = cover_letter_file.name
        if cover_letter_file_path.endswith(".pdf"):
            cover_letter_format = extract_text_from_pdf(cover_letter_file_path)
        elif cover_letter_file_path.endswith(".docx"):
            cover_letter_format = extract_text_from_docx(cover_letter_file)
        else:
            return None, "Error: Unsupported file format for cover letter. Please upload a .pdf or .docx file."
    else:
        cover_letter_format = ""
    
    
    inputs = {
        "resume": resume_content,
        "linkedin": linkedin_profile,
        "job_description": job_description,
        "cover_letter_format": cover_letter_format
    }
    
    # Calculate input tokens
    resume_tokens = count_tokens(resume_content)
    linkedin_tokens = count_tokens(linkedin_profile)
    job_description_tokens = count_tokens(job_description)
    cover_letter_format_tokens = count_tokens(cover_letter_format)
    input_tokens = resume_tokens + linkedin_tokens + job_description_tokens + cover_letter_format_tokens

    # Run the sequential chain
    try:
        outputs = sequential_chain(inputs)
        cover_letter_final = outputs["cover_letter_final"]
        output_tokens = count_tokens(cover_letter_final)
    except Exception as e:
        return None, f"Error during processing: {e}"
    
    # Total tokens
    total_tokens = input_tokens + output_tokens


     # Return the outputs: cover letter final, message, and LinkedIn profile content
    return cover_letter_final, message, input_tokens, output_tokens, total_tokens

# %%
#Use Gradio to generate web UI
import gradio as gr

gr.close_all()
demo = gr.Interface(fn=cover_letter_gen, 
                    inputs=[gr.File(label="Upload Resume (PDF) (Required)"),
                            gr.Textbox(lines=1, placeholder="Enter LinkedIn profile URL (Optional)", label="LinkedIn Profile URL"),
                            gr.Textbox(lines=1, placeholder="Enter job description URL (Required)", label="Job Description URL"),
                            gr.Textbox(lines=5, placeholder="Enter job description manually (if URL fetch fails)", label="Manual Job Description"),
                            gr.File(label="Upload Cover Letter Format (PDF or DOCX) (Optional)")
                    ],
                    outputs=[gr.Textbox(label="Cover Letter Final"),
                             gr.Textbox(label="Message"),
                             gr.Textbox(label="Input Tokens"),
                             gr.Textbox(label="Output Tokens"),
                             gr.Textbox(label="Total Tokens")
                    ],
                    title="Cover Letter Generator",
                    description="Upload your resume, Linkedin profile, and job description URL to generate your customized cover letter"
                   )
#demo.launch(share=True)
demo.launch()
# Out:
# Closing server running on port: 7861
# Running on local URL:  http://127.0.0.1:7861
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Rate limiter: Delaying for 2.65 seconds.
#
#
# > Entering new SequentialChain chain...
#
# > Finished chain.
